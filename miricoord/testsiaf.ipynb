# %%
import pysiaf

# %%
siaf=pysiaf.Siaf('MIRI')
newsiaf=pysiaf.Siaf('MIRI',basepath='/Users/dlaw/jwcode/pysiaf/pysiaf/pre_delivery_data/MIRI')

# %%
import pylab as pl

# %%
pl.figure(figsize=(15, 15), facecolor='w', edgecolor='k'); pl.clf()
for aperture_name, aperture in siaf.apertures.items():
        aperture.plot()
pl.ylim([-440,-310])
pl.xlim([-370,-510])
pl.show()

# %%
pl.figure(figsize=(15, 15), facecolor='w', edgecolor='k'); pl.clf()
for aperture_name, aperture in newsiaf.apertures.items():
        aperture.plot()
pl.ylim([-440,-310])
pl.xlim([-370,-510])
pl.show()

# %%
pl.figure(figsize=(15, 15), facecolor='w', edgecolor='k'); pl.clf()
siaf['MIRIM_SLIT'].plot()
newsiaf['MIRIM_SLIT'].plot()
pl.show()
