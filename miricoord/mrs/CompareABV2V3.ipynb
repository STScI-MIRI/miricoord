# %%
# Compare the alpha-beta to V2V3 distortions of two different models
# (NOT WRITTEN YET)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import miricoord.mrs.mrs_tools as mt

# %%
newmodel='flt4'
oldmodel='flt3'
ntxt='FLT-4'
otxt='FLT-3'

# %%
# Define x vectors up slices
cvec=['1A','1B','1C','2A','2B','2C','3A','3B','3C','4A','4B','4C']

x_channels=np.zeros(12)
x_channels[0]=240
x_channels[1]=240
x_channels[2]=242

x_channels[3]=718
x_channels[4]=714
x_channels[5]=717

x_channels[6]=763
x_channels[7]=734
x_channels[8]=733

x_channels[9]=194
x_channels[10]=191
x_channels[11]=194

# %%
al_old=np.zeros([1024,12])
al_new=np.zeros([1024,12])

# %%
mt.set_toolversion(oldmodel)
for ii in range(0,12):
    xvec=np.zeros(1024)+x_channels[ii]
    yvec=np.arange(1024)
    vals=mt.xytoabl(xvec,yvec,cvec[ii])
    al_old[:,ii]=vals['alpha']
    
mt.set_toolversion(newmodel)
for ii in range(0,12):
    xvec=np.zeros(1024)+x_channels[ii]
    yvec=np.arange(1024)
    vals=mt.xytoabl(xvec,yvec,cvec[ii])
    al_new[:,ii]=vals['alpha']

# %%
plt.figure(figsize=(7,5),dpi=150)
ax = plt.gca()

for ii in range(0,12):
    thisnew=al_new[:,ii]
    thisold=al_old[:,ii]
    indx=np.where((thisnew > -10)&(thisold > -10))
    plt.plot(thisnew[indx]-thisold[indx],label=cvec[ii])
    
plt.legend()
plt.ylabel('Offset (arcsec)')
plt.title(ntxt+' vs '+ otxt+ ' alpha solution')
# Out:
# Text(0.5, 1.0, 'FLT-4 vs FLT-3 alpha solution')
